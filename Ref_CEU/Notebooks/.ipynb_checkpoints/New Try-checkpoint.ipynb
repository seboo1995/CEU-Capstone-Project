# %% [markdown]
# # ARIMAX

# %%
import pandas as pd
import pyflux as pf

# %%
data = pd.read_csv("Final.csv")
data.rename(columns = {"Unnamed: 0":"Date"},inplace=True)
data.set_index("Date",inplace=True)
data.columns = [i.replace(" ","_") for  i in data.columns]
data
# Out:
#                     zone_name   hh_zonal  nhh_zonal   residual    year  \
# Date
# 2007-12-31  Southern Scotland   6.362303   0.830136  14.061505  2007.0
# 2007-12-31           Northern   9.884146   1.287148  14.061505  2007.0
# 2007-12-31         North West  13.646168   1.734890  14.061505  2007.0
# 2007-12-31          Yorkshire  13.615270   1.750626  14.061505  2007.0
# 2007-12-31   N Wales & Mersey  14.084355   1.805802  14.061505  2007.0
# ...                       ...        ...        ...        ...     ...
# 2018-12-31        South Wales  45.804410   5.552697  46.933426  2018.0
# 2018-12-31         South East  52.110398   7.713198  46.933426  2018.0
# 2018-12-31             London  54.906683   6.106170  46.933426  2018.0
# 2018-12-31           Southern  53.419807   7.317489  46.933426  2018.0
# 2018-12-31      South Western  51.867520   7.560093  46.933426  2018.0
#
#                log_nd  inflation  operation_cost  amortization  revenue  \
# Date
# 2007-12-31  20.319042   5.588235          1433.0         245.0   1991.0
# 2007-12-31  20.319042   5.588235          1433.0         245.0   1991.0
# 2007-12-31  20.319042   5.588235          1433.0         245.0   1991.0
# 2007-12-31  20.319042   5.588235          1433.0         245.0   1991.0
# 2007-12-31  20.319042   5.588235          1433.0         245.0   1991.0
# ...               ...        ...             ...           ...      ...
# 2018-12-31  20.087578   6.866538          3125.0         464.0   4158.0
# 2018-12-31  20.087578   6.866538          3125.0         464.0   4158.0
# 2018-12-31  20.087578   6.866538          3125.0         464.0   4158.0
# 2018-12-31  20.087578   6.866538          3125.0         464.0   4158.0
# 2018-12-31  20.087578   6.866538          3125.0         464.0   4158.0
#
#             total_liabilities  net_payroll_costs  number_of_employees    tax  \
# Date
# 2007-12-31             5887.0               89.0               2073.0  126.0
# 2007-12-31             5887.0               89.0               2073.0  126.0
# 2007-12-31             5887.0               89.0               2073.0  126.0
# 2007-12-31             5887.0               89.0               2073.0  126.0
# 2007-12-31             5887.0               89.0               2073.0  126.0
# ...                       ...                ...                  ...    ...
# 2018-12-31            10682.0              181.0               3679.0  165.0
# 2018-12-31            10682.0              181.0               3679.0  165.0
# 2018-12-31            10682.0              181.0               3679.0  165.0
# 2018-12-31            10682.0              181.0               3679.0  165.0
# 2018-12-31            10682.0              181.0               3679.0  165.0
#
#              adj_close        volume
# Date
# 2007-12-31  393.191688  3.193817e+08
# 2007-12-31  393.191688  3.193817e+08
# 2007-12-31  393.191688  3.193817e+08
# 2007-12-31  393.191688  3.193817e+08
# 2007-12-31  393.191688  3.193817e+08
# ...                ...           ...
# 2018-12-31  739.531153  2.155613e+08
# 2018-12-31  739.531153  2.155613e+08
# 2018-12-31  739.531153  2.155613e+08
# 2018-12-31  739.531153  2.155613e+08
# 2018-12-31  739.531153  2.155613e+08
#
# [166 rows x 16 columns]

# %%
temp = data[data.zone_name == "Northern"]
temp.drop("zone_name",axis=1,inplace=True)

# %%
model = pf.ARIMAX(data=temp, formula='hh_zonal~1+log_nd',ar=1, ma=0)
x = model.fit("MLE")
x.summary()
# Out:
# Normal ARIMAX(1,0,0)
# ======================================================= ==================================================
# Dependent Variable: hh_zonal                            Method: MLE
# Start Date: 2008-12-31                                  Log Likelihood: -29.3678
# End Date: 2018-12-31                                    AIC: 66.7357
# Number of observations: 11                              BIC: 68.3273
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.9533     0.5492     1.7358   0.0826   (-0.1231 | 2.0296)
# Beta 1                                   0.0092     1703.9124  0.0      1.0      (-3339.6591 | 3339.6776)
# Beta log_nd                              0.1771     83.7515    0.0021   0.9983   (-163.9759 | 164.3301)
# Normal Scale                             3.4934
# ==========================================================================================================

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
model.plot_predict(h=10,oos_data=temp,past_values=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-279-334586a2260a> in <module>
#       1 plt.figure(figsize=(10,10))
# ----> 2 model.plot_predict(h=10,oos_data=temp,past_values=4)
#
# ~/anaconda3/lib/python3.7/site-packages/pyflux/arma/arimax.py in plot_predict(self, h, past_values, intervals, oos_data, **kwargs)
#     816                 for count, pre in enumerate(error_bars):
#     817                     plt.fill_between(date_index[-h-1:], error_bars[count], error_bars[-count-1],alpha=alpha[count])
# --> 818             plt.plot(plot_index,plot_values)
#     819             plt.title("Forecast for " + self.data_name)
#     820             plt.xlabel("Time")
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (11,) and (14,)

# %%
model.plot_fit()

# %% [markdown]
# ###

# %%
model.plot_predict_is(h=6)

# %%
model.predict_is(oos_data= temp,h=3)
# Out:
#              hh_zonal
# Date
# 2016-12-31  39.601656
# 2017-12-31  52.558930
# 2018-12-31  47.904116

# %%
model.predict(oos_data=temp)
# Out:
#              hh_zonal
# Date
# 2014-12-31  39.656802
# 2015-12-31  41.409792
# 2016-12-31  43.071373
# 2017-12-31  44.658304
# 2018-12-31  46.164183

# %%
model.latent_variables.get_z_values()
# Out:
# array([0.95325668, 0.0092395 , 0.1770959 , 1.25086721])

# %%
model.predict(oos_data=temp,h=10)
# Out:
#              hh_zonal
# Date
# 2009-12-31  15.175566
# 2010-12-31  11.081468
# 2011-12-31  13.960536
# 2012-12-31  15.459391
# 2013-12-31  16.009763
# 2014-12-31  19.463818
# 2015-12-31  21.902425
# 2016-12-31  25.251313
# 2017-12-31  31.511777
# 2018-12-31  43.202095

# %%
model.plot_predict(h=5,oos_data=temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-d8b17d82968f> in <module>
# ----> 1 model.plot_predict(h=5,oos_data=temp)
#
# ~/anaconda3/lib/python3.7/site-packages/pyflux/arma/arimax.py in plot_predict(self, h, past_values, intervals, oos_data, **kwargs)
#     816                 for count, pre in enumerate(error_bars):
#     817                     plt.fill_between(date_index[-h-1:], error_bars[count], error_bars[-count-1],alpha=alpha[count])
# --> 818             plt.plot(plot_index,plot_values)
#     819             plt.title("Forecast for " + self.data_name)
#     820             plt.xlabel("Time")
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (11,) and (16,)

# %%
model = pf.DynReg('hh_zonal ~ log_nd+operation_cost+revenue', data=temp)

# %%
x = model.fit()

# %%
x.summary()
# Out:
# Dynamic Linear Regression
# ======================================================= ==================================================
# Dependent Variable: hh_zonal                            Method: MLE
# Start Date: 2007-12-31                                  Log Likelihood: -47.5491
# End Date: 2018-12-31                                    AIC: 105.0982
# Number of observations: 12                              BIC: 107.5228
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# Sigma^2 irregular                        0.2071
# Sigma^2 1                                0.5324
# Sigma^2 log_nd                           0.0373
# Sigma^2 operation_cost                   0.0
# Sigma^2 revenue                          0.0
# ==========================================================================================================

# %%
model.plot_fit(figsize=(20,20))

# %%
model.plot_predict(h=10,oos_data=temp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-5baf63670469> in <module>
# ----> 1 model.plot_predict(h=10,oos_data=temp)
#
# ~/anaconda3/lib/python3.7/site-packages/pyflux/ssm/dynlin.py in plot_predict(self, h, past_values, intervals, oos_data, **kwargs)
#     259                 plt.show()
#     260             else:
# --> 261                 a, P = self._forecast_model(self.latent_variables.get_z_values(), h)
#     262                 plot_values = a[0][-h-past_values:]
#     263                 forecasted_values = a[0][-h:]
#
# TypeError: _forecast_model() missing 1 required positional argument: 'h'

# %%
import operator
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
features_dict = {}
from sklearn.feature_selection import SelectKBest,SelectFromModel
def create_lasso_feat_plot(df,zone_name,var="hh_zonal",alpha=0.01):
    #creating vectors
    print('For',zone_name)

    
    temp = df[df.zone_name == zone_name]
    temp.drop(["zone_name",'year'],axis=1,inplace=True)
    X = temp.drop(var,axis=1)
    y = temp[[var]]
    #print(temp)
    lasso = Lasso()
    
    params = {"alpha":[1e-15,1e-10,1e-3,1e-2,1,5,10,20]}
    #print("PIN")
    lasso_reg = GridSearchCV(lasso,params,scoring="neg_mean_squared_error",cv=5)
    #print("PIN")
    lasso_reg.fit(X,y)
    
    sel_ = SelectFromModel(lasso_reg.best_estimator_)
    sel_.fit(X,y)
    
  
    
    
    
    
    
    coef_lasso = pd.Series(lasso_reg.best_estimator_.coef_,index = X.columns)
    print("LASSO coef:")
    print(coef_lasso)
    print('***************************************')
    selected_feat = X.columns[(sel_.get_support())]
    print('For',zone_name)
    print('total features: {}'.format((X.shape[1])))
    print('selected features: {}'.format(len(selected_feat)))
    print('features with coefficients shrank to zero: {}'.format(
          np.sum(sel_.estimator_.coef_ == 0))) 
    
    indicies = [i for i, x in enumerate(sel_.get_support()) if x]
    selected_features = operator.itemgetter(*indicies)(X.columns)
    print("\n")
    print("Selected features: ",selected_features)
    features_dict[zone_name] = selected_features
    print('***********************************************************')

# %%
zones = data.zone_name.unique()
### The sign of the coeff gives the sign of the correlation between the feature and the residual.
for i in zones:
    create_lasso_feat_plot(data,zone_name=i,var="hh_zonal")
# Out:
# For Southern Scotland
# LASSO coef:
# nhh_zonal              4.840465e+00
# residual               5.437024e-02
# log_nd                -5.085465e-01
# inflation             -3.348963e-02
# operation_cost        -4.466782e-03
# amortization           1.102435e-02
# revenue                2.604892e-03
# total_liabilities     -4.610505e-04
# net_payroll_costs      5.308114e-02
# number_of_employees   -9.364304e-04
# tax                    9.183106e-03
# adj_close              8.984093e-03
# volume                -7.293294e-09
# dtype: float64
# ***************************************
# For Southern Scotland
# total features: 13
# selected features: 12
# features with coefficients shrank to zero: 0
#
#
# Selected features:  ('nhh_zonal', 'residual', 'log_nd', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For Northern
# LASSO coef:
# nhh_zonal              3.895637e+00
# residual               1.589639e-01
# log_nd                -5.710601e+01
# inflation             -8.605654e-02
# operation_cost        -9.893929e-03
# amortization           4.531403e-02
# revenue               -5.321727e-04
# total_liabilities     -3.592211e-04
# net_payroll_costs      2.473500e-02
# number_of_employees    1.664262e-04
# tax                    3.214747e-03
# adj_close              2.703450e-03
# volume                -1.156298e-08
# dtype: float64
# ***************************************
# For Northern
# total features: 13
# selected features: 12
# features with coefficients shrank to zero: 0
#
#
# Selected features:  ('nhh_zonal', 'residual', 'log_nd', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For North West
# LASSO coef:
# nhh_zonal              0.000000e+00
# residual               0.000000e+00
# log_nd                 0.000000e+00
# inflation              0.000000e+00
# operation_cost         8.533196e-03
# amortization           0.000000e+00
# revenue                3.968157e-03
# total_liabilities     -2.228977e-03
# net_payroll_costs      0.000000e+00
# number_of_employees    6.359380e-03
# tax                    1.522195e-02
# adj_close              2.146861e-02
# volume                 1.141373e-08
# dtype: float64
# ***************************************
# For North West
# total features: 13
# selected features: 6
# features with coefficients shrank to zero: 6
#
#
# Selected features:  ('operation_cost', 'revenue', 'total_liabilities', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For Yorkshire
# LASSO coef:
# nhh_zonal              0.000000e+00
# residual               3.860568e-02
# log_nd                 0.000000e+00
# inflation              0.000000e+00
# operation_cost         5.743776e-03
# amortization           1.970375e-02
# revenue                4.319773e-03
# total_liabilities     -2.604470e-03
# net_payroll_costs      0.000000e+00
# number_of_employees    6.002211e-03
# tax                    1.913968e-02
# adj_close              2.220418e-02
# volume                 2.313379e-09
# dtype: float64
# ***************************************
# For Yorkshire
# total features: 13
# selected features: 8
# features with coefficients shrank to zero: 4
#
#
# Selected features:  ('residual', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For N Wales & Mersey
# LASSO coef:
# nhh_zonal              3.291543e+00
# residual               6.127014e-02
# log_nd                -0.000000e+00
# inflation              7.139436e-02
# operation_cost         1.139621e-02
# amortization           1.146575e-02
# revenue               -1.142890e-03
# total_liabilities     -1.124316e-03
# net_payroll_costs     -2.823805e-02
# number_of_employees    3.374365e-03
# tax                    7.896500e-05
# adj_close             -1.273024e-03
# volume                 5.342598e-09
# dtype: float64
# ***************************************
# For N Wales & Mersey
# total features: 13
# selected features: 11
# features with coefficients shrank to zero: 1
#
#
# Selected features:  ('nhh_zonal', 'residual', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For East Midlands
# LASSO coef:
# nhh_zonal              0.000000e+00
# residual               2.223931e-02
# log_nd                 0.000000e+00
# inflation              0.000000e+00
# operation_cost         5.285748e-03
# amortization           3.354969e-02
# revenue                5.193499e-03
# total_liabilities     -2.391612e-03
# net_payroll_costs      0.000000e+00
# number_of_employees    4.245718e-03
# tax                    1.739944e-02
# adj_close              1.866610e-02
# volume                 7.466750e-10
# dtype: float64
# ***************************************
# For East Midlands
# total features: 13
# selected features: 8
# features with coefficients shrank to zero: 4
#
#
# Selected features:  ('residual', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For Midlands
# LASSO coef:
# nhh_zonal              3.576688e+00
# residual               5.729624e-02
# log_nd                 0.000000e+00
# inflation              9.324220e-02
# operation_cost        -1.196528e-03
# amortization          -1.048470e-02
# revenue                6.589996e-03
# total_liabilities     -6.503548e-04
# net_payroll_costs      3.329048e-02
# number_of_employees    3.845595e-04
# tax                    1.007594e-02
# adj_close              9.836968e-03
# volume                 1.126115e-08
# dtype: float64
# ***************************************
# For Midlands
# total features: 13
# selected features: 11
# features with coefficients shrank to zero: 1
#
#
# Selected features:  ('nhh_zonal', 'residual', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For Eastern
# LASSO coef:
# nhh_zonal              2.164495e+00
# residual               4.998623e-02
# log_nd                -0.000000e+00
# inflation              2.932484e-02
# operation_cost         3.240694e-03
# amortization           1.292894e-02
# revenue                3.064855e-03
# total_liabilities     -1.105795e-03
# net_payroll_costs      2.251689e-02
# number_of_employees    5.560312e-04
# tax                    2.028087e-02
# adj_close              1.843121e-02
# volume                -2.361668e-09
# dtype: float64
# ***************************************
# For Eastern
# total features: 13
# selected features: 11
# features with coefficients shrank to zero: 1
#
#
# Selected features:  ('nhh_zonal', 'residual', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For South Wales
# LASSO coef:
# nhh_zonal              0.000000e+00
# residual               0.000000e+00
# log_nd                -0.000000e+00
# inflation              0.000000e+00
# operation_cost         1.113790e-02
# amortization           0.000000e+00
# revenue                2.607329e-03
# total_liabilities     -1.656852e-04
# net_payroll_costs      0.000000e+00
# number_of_employees   -0.000000e+00
# tax                    0.000000e+00
# adj_close              5.383233e-03
# volume                 2.592994e-08
# dtype: float64
# ***************************************
# For South Wales
# total features: 13
# selected features: 4
# features with coefficients shrank to zero: 8
#
#
# Selected features:  ('operation_cost', 'revenue', 'total_liabilities', 'adj_close')
# ***********************************************************
# For South East
# LASSO coef:
# nhh_zonal              6.806474e-01
# residual              -1.349271e-02
# log_nd                -0.000000e+00
# inflation              9.829863e-02
# operation_cost         8.736831e-03
# amortization           9.716565e-03
# revenue                3.523711e-03
# total_liabilities     -1.289635e-03
# net_payroll_costs      9.491246e-03
# number_of_employees    2.146296e-04
# tax                    2.780821e-02
# adj_close              2.354576e-02
# volume                -3.460978e-10
# dtype: float64
# ***************************************
# For South East
# total features: 13
# selected features: 11
# features with coefficients shrank to zero: 1
#
#
# Selected features:  ('nhh_zonal', 'residual', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For London
# LASSO coef:
# nhh_zonal              0.000000e+00
# residual               3.661280e-02
# log_nd                 0.000000e+00
# inflation              0.000000e+00
# operation_cost         7.340476e-03
# amortization           2.282542e-02
# revenue                5.032481e-03
# total_liabilities     -2.730183e-03
# net_payroll_costs      6.808100e-03
# number_of_employees    4.519944e-03
# tax                    2.800077e-02
# adj_close              2.103373e-02
# volume                 3.496015e-09
# dtype: float64
# ***************************************
# For London
# total features: 13
# selected features: 9
# features with coefficients shrank to zero: 3
#
#
# Selected features:  ('residual', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For Southern
# LASSO coef:
# nhh_zonal              1.313193e+00
# residual               3.648006e-02
# log_nd                -0.000000e+00
# inflation              4.547972e-02
# operation_cost         4.697197e-03
# amortization           8.936137e-03
# revenue                3.553780e-03
# total_liabilities     -1.254813e-03
# net_payroll_costs      3.899635e-02
# number_of_employees    1.608092e-03
# tax                    1.804028e-02
# adj_close              1.937545e-02
# volume                 1.260386e-09
# dtype: float64
# ***************************************
# For Southern
# total features: 13
# selected features: 11
# features with coefficients shrank to zero: 1
#
#
# Selected features:  ('nhh_zonal', 'residual', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************
# For South Western
# LASSO coef:
# nhh_zonal              0.000000e+00
# residual               0.000000e+00
# log_nd                -0.000000e+00
# inflation              0.000000e+00
# operation_cost         8.225185e-03
# amortization           0.000000e+00
# revenue                3.358559e-03
# total_liabilities      0.000000e+00
# net_payroll_costs      0.000000e+00
# number_of_employees    2.880785e-03
# tax                    0.000000e+00
# adj_close              8.967502e-03
# volume                 2.206957e-08
# dtype: float64
# ***************************************
# For South Western
# total features: 13
# selected features: 4
# features with coefficients shrank to zero: 8
#
#
# Selected features:  ('operation_cost', 'revenue', 'number_of_employees', 'adj_close')
# ***********************************************************
# For Northern Scotland
# LASSO coef:
# nhh_zonal              2.986271e+00
# residual               4.360072e-01
# log_nd                 1.261617e+01
# inflation              8.527158e-01
# operation_cost         8.456638e-03
# amortization          -2.482346e-02
# revenue               -1.560615e-02
# total_liabilities     -2.639135e-03
# net_payroll_costs      2.505200e-01
# number_of_employees   -1.195281e-02
# tax                    1.107693e-01
# adj_close              8.894951e-02
# volume                -1.593991e-07
# dtype: float64
# ***************************************
# For Northern Scotland
# total features: 13
# selected features: 12
# features with coefficients shrank to zero: 0
#
#
# Selected features:  ('nhh_zonal', 'residual', 'log_nd', 'inflation', 'operation_cost', 'amortization', 'revenue', 'total_liabilities', 'net_payroll_costs', 'number_of_employees', 'tax', 'adj_close')
# ***********************************************************

# %%
features_dict["Northern"]
# Out:
# ('nhh_zonal',
#  'residual',
#  'log_nd',
#  'inflation',
#  'operation_cost',
#  'amortization',
#  'revenue',
#  'total_liabilities',
#  'net_payroll_costs',
#  'number_of_employees',
#  'tax',
#  'adj_close')

# %%
temp[list(features_dict["Northern"])]
# Out:
#             nhh_zonal   residual     log_nd  inflation  operation_cost  \
# Date
# 2007-12-31   1.287148  14.061505  20.319042   5.588235          1433.0
# 2008-12-31   1.424364  15.403402  20.313523  17.130920          1461.0
# 2009-12-31   1.598288  16.943694  20.260050   0.237812          1848.0
# 2010-12-31   1.993796  18.558560  20.277094   5.812574          1693.0
# 2011-12-31   2.170176   3.607933  20.238285  11.883410          1730.0
# 2012-12-31   2.720973  22.828373  20.241926   5.010020          1948.0
# 2013-12-31   3.079732  25.408454  20.230591   3.339695          2102.0
# 2014-12-31   3.666178  30.052442  20.180207   0.092336          2375.0
# 2015-12-31   4.283661  35.634955  20.151214  -7.749077          2529.0
# 2016-12-31   6.765895  45.333826  20.127212  -2.500000          2818.0
# 2017-12-31   5.943493  47.260756  20.091862   6.051282          3093.0
# 2018-12-31   4.999041  46.933426  20.087578   6.866538          3125.0
#
#             amortization  revenue  total_liabilities  net_payroll_costs  \
# Date
# 2007-12-31         245.0   1991.0             5887.0               89.0
# 2008-12-31         244.0   2106.0             6299.0               94.0
# 2009-12-31         221.0   2566.0             6681.0              111.0
# 2010-12-31         240.0   2484.0             6885.0               97.0
# 2011-12-31         264.0   2549.0             7022.0              112.0
# 2012-12-31         276.0   2813.0             8178.0              121.0
# 2013-12-31         325.0   3111.0             9854.0              104.0
# 2014-12-31         341.0   3393.0             9559.0              120.0
# 2015-12-31         375.0   3713.0            10467.0              133.0
# 2016-12-31         390.0   3979.0            10405.0              141.0
# 2017-12-31         419.0   4493.0            10801.0              156.0
# 2018-12-31         464.0   4158.0            10682.0              181.0
#
#             number_of_employees    tax   adj_close
# Date
# 2007-12-31               2073.0  126.0  393.191688
# 2008-12-31               2288.0  140.0  371.787890
# 2009-12-31               2352.0  153.0  335.913735
# 2010-12-31               2488.0  183.0  367.357994
# 2011-12-31               2784.0  139.0  434.997279
# 2012-12-31               2978.0  101.0  508.046112
# 2013-12-31               3229.0  161.0  605.459168
# 2014-12-31               3044.0   79.0  725.807424
# 2015-12-31               3270.0  203.0  779.542343
# 2016-12-31               3520.0  114.0  921.059987
# 2017-12-31               3692.0   87.0  854.296926
# 2018-12-31               3679.0  165.0  739.531153

# %%
model = pf.VAR(data=temp[["nhh_zonal","hh_zonal"]], lags=1)

# %%
model

# %%
model_fit  = model.fit()

# %%
model_fit.summary()
# Out:
# VAR(1)
# ======================================================= ==================================================
# Dependent Variable: nhh_zonal,hh_zonal                  Method: OLS
# Start Date: 2008-12-31                                  Log Likelihood: -14.3274
# End Date: 2018-12-31                                    AIC: 46.6547
# Number of observations: 11                              BIC: 50.2358
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# nhh_zonal Constant                       -0.6883    0.2768     -2.4865  0.0129   (-1.2309 | -0.1458)
# nhh_zonal AR(1)                          -2.7114    0.7535     -3.5983  0.0003   (-4.1883 | -1.2345)
# hh_zonal to nhh_zonal AR(1)              0.5711     0.4684     1.2194   0.2227   (-0.3469 | 1.4892)
# hh_zonal Constant                        -2.2749    1.2749     -1.7843  0.0744   (-4.7738 | 0.224)
# hh_zonal AR(1)                           -16.3513   0.0744     -219.913 0.0      (-16.497 | -16.2056)
# nhh_zonal to hh_zonal AR(1)              3.5294     0.2024     17.4388  0.0      (3.1327 | 3.9261)
# ==========================================================================================================

# %%
model.predict_is(h=5)
# Out:
#             nhh_zonal   hh_zonal
# Date
# 2014-12-31   3.479961  25.257276
# 2015-12-31   4.331131  32.321789
# 2018-12-31          3125.0         464.0   4158.0            10682.0  ...
# 2018-12-31          3125.0         464.0   4158.0            10682.0  ...
# 2018-12-31          3125.0         464.0   4158.0            10682.0  ...
#
#             zone_name_N Wales & Mersey  zone_name_North West  \
# Date
# 2007-12-31                           0                     0
# 2007-12-31                           0                     0
# 2007-12-31                           0                     1
# 2007-12-31                           0                     0
# 2007-12-31                           1                     0
# ...                                ...                   ...
# 2018-12-31                           0                     0
# 2018-12-31                           0                     0
# 2018-12-31                           0                     0
# 2018-12-31                           0                     0
# 2018-12-31                           0                     0
#
#             zone_name_Northern  zone_name_Northern Scotland  \
# Date
# 2007-12-31                   0                            0
# 2007-12-31                   1                            0
# 2007-12-31                   0                            0
# 2007-12-31                   0                            0
# 2007-12-31                   0                            0
# ...                        ...                          ...
# 2018-12-31                   0                            0
# 2018-12-31                   0                            0
# 2018-12-31                   0                            0
# 2018-12-31                   0                            0
# 2018-12-31                   0                            0
#
#             zone_name_South East  zone_name_South Wales  \
# Date
# 2007-12-31                     0                      0
# 2007-12-31                     0                      0
# 2007-12-31                     0                      0
# 2007-12-31                     0                      0
# 2007-12-31                     0                      0
# ...                          ...                    ...
# 2018-12-31                     0                      1
# 2018-12-31                     1                      0
# 2018-12-31                     0                      0
# 2018-12-31                     0                      0
# 2018-12-31                     0                      0
#
#             zone_name_South Western  zone_name_Southern  \
# Date
# 2007-12-31                        0                   0
# 2007-12-31                        0                   0
# 2007-12-31                        0                   0
# 2007-12-31                        0                   0
# 2007-12-31                        0                   0
# ...                             ...                 ...
# 2018-12-31                        0                   0
# 2018-12-31                        0                   0
# 2018-12-31                        0                   0
# 2018-12-31                        0                   1
# 2018-12-31                        1                   0
#
#             zone_name_Southern Scotland  zone_name_Yorkshire
# Date
# 2007-12-31                            1                    0
# 2007-12-31                            0                    0
# 2007-12-31                            0                    0
# 2007-12-31                            0                    1
# 2007-12-31                            0                    0
# ...                                 ...                  ...
# 2018-12-31                            0                    0
# 2018-12-31                            0                    0
# 2018-12-31                            0                    0
# 2018-12-31                            0                    0
# 2018-12-31                            0                    0
#
# [166 rows x 29 columns]

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet

# %%
el = ElasticNet(positive=True,normalize=True)

# %%
X = pd.get_dummies(data).drop(["hh_zonal","year"],axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
y= pd.get_dummies(data).hh_zonal

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=42)

# %%
sc = StandardScaler()

# %%
el.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=True, positive=True, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
pred = el.predict(X_test)
pred
# Out:
# array([29.72988152, 30.16046301, 29.47357881, 29.19133102, 29.67850647,
#        29.1440593 , 29.75811395, 29.50870985, 30.35413616, 29.78593589,
#        29.07016661, 29.14141307, 29.04422691, 29.26725661, 29.08743447,
#        29.14110718, 30.15466385])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(pred,y_test)
# Out:
# 157.8169797811355

# %%
plt.figure(figsize=(10,10))
pd.Series(el.coef_,index=X.columns).plot(kind="barh")
