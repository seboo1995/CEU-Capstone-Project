# %%
# %pwd
# Out:
# '/home/sebair/CEU-Capstone-Project/Jupyter_Notebooks/reports_from_nget'

# %%
# %ls
# Out:
#  2-nget-stat-and-regsmodel-2016-250716-web-version.pdf
# 'FY19 NGET Statutory Accounts 26072019.pdf'
#  national-grid-electricity-transmission-plc-regulatory-accounting-statements-2014-15.pdf
#  ng2007-regulatoryaccounts2007310707published.pdf
#  ng2008-ngetregaccounts0708forpublication.pdf
#  ng2009-ngetregsproof2009v43publish.pdf
#  ng2010-ngetregs200910publish.pdf
#  ng2011-ngetregulatoryaccounts201011.pdf
#  ng-2012nget-regulatory-accounts-2012-public.pdf
#  nget-plc-regulatory-accounting-statements-2013-14.pdf
# 'NGET Reg Accounts.pdf'
# 'NGET Regulatory Accounts website version.pdf'
#  Untitled.ipynb

# %% [markdown]
# # ! NEED TO FIND A WAY TO READ THEM

# %%
import tabula
import numpy as np

# %%
tass = tabula.read_pdf("2-nget-stat-and-regsmodel-2016-250716-web-version.pdf",pages = 42)

# %%
tass[0]
# Out:
#                                            Unnamed: 0 Unnamed: 1   2016  \
# 0                                                 NaN      Notes     £m
# 1                                             Revenue       1(a)    NaN
# 2                            Exceptional other income          3    NaN
# 3                                     Operating costs          2    NaN
# 4                                    Operating profit        NaN    NaN
# 5                            Before exceptional items       1(b)  1,161
# 6                                   Exceptional items          3      -
# 7                              Total operating profit       1(b)    NaN
# 8                                      Finance income          4    NaN
# 9                                       Finance costs        NaN    NaN
# 10        Before exceptional items and remeasurements          4  (128)
# 11               Exceptional items and remeasurements       3, 4   (12)
# ...

# %%
for j in tass:
    for k in j.apply(lambda row: row.astype(str).str.contains('Operating costs').any(), axis=1):
        if k:
            temp = j
            break
            break

# %%
for j in temp.iteritems():
    for k in j:
        print("_____________")
        print(k)
# Out:
# _____________
# Revenue
# _____________
# 0                                 Operating costs
# 1                                Operating profit
# 2                        Before exceptional items
# 3                               Exceptional items
# 4                          Total operating profit
# 5              Interest income and similar income
# 6        Interest expense and other finance costs
# 7     Before exceptional items and remeasurements
# 8            Exceptional items and remeasurements
# 9                                             NaN
# 10                              Profit before tax
# 11    Before exceptional items and remeasurements
# 12           Exceptional items and remeasurements
# 13                        Total profit before tax
# 14                                       Taxation
# 15    Before exceptional items and remeasurements
# 16           Exceptional items and remeasurements
# 17                                 Total taxation
# ...

# %%
len(tass)
# Out:
# 18

# %% [markdown]
# # For now I will input them manually

# %%
operation_cost = {"2007":1433,
                 "2008":1461,
                 "2009":1848,
                 "2010":1693,
                 "2011":1730,
                 "2012":1948,
                 "2013":2102,
                 "2014": 2375,
                 "2015": 2529,
                  "2016":2818,
                  "2017":3093,
                  "2018": 3125,
                  "2019": 2355
                 }
operation_cost
# Out:
# {'2007': 1433,
#  '2008': 1461,
#  '2009': 1848,
#  '2010': 1693,
#  '2011': 1730,
#  '2012': 1948,
#  '2013': 'NA',
#  '2014': 2375,
#  '2015': 2529,
#  '2016': 2818,
#  '2017': 3093,
#  '2018': 3125,
#  '2019': 2355}

# %%
amortisation_cost = {"2007":245,
                 "2008":244,
                 "2009":221,
                 "2010":240,
                 "2011":264,
                 "2012":276,
                 "2013":2102,
                 "2014": 341,
                 "2015": 375,
                  "2016":390,
                  "2017":419,
                  "2018": 464,
                  "2019": 492
                 }
amortisation_cost
# Out:
# {'2007': 245,
#  '2008': 244,
#  '2009': 221,
#  '2010': 240,
#  '2011': 264,
#  '2012': 276,
#  '2013': 'NA',
#  '2014': 341,
#  '2015': 375,
#  '2016': 390,
#  '2017': 419,
#  '2018': 464,
#  '2019': 492}

# %%
import pandas as pd

# %%
new_df = pd.DataFrame.from_dict([operation_cost,amortisation_cost])
new_df
# Out:
#    2007  2008  2009  2010  2011  2012 2013  2014  2015  2016  2017  2018  2019
# 0  1433  1461  1848  1693  1730  1948   NA  2375  2529  2818  3093  3125  2355
# 1   245   244   221   240   264   276   NA   341   375   390   419   464   492

# %%
new_df = new_df.transpose()
new_df = new_df.reset_index()
new_df.columns = ["year","operation_cost","amortization"]
new_df
# Out:
#     year operation_cost amortization
# 0   2007           1433          245
# 1   2008           1461          244
# 2   2009           1848          221
# 3   2010           1693          240
# 4   2011           1730          264
# 5   2012           1948          276
# 6   2013             NA           NA
# 7   2014           2375          341
# 8   2015           2529          375
# 9   2016           2818          390
# 10  2017           3093          419
# 11  2018           3125          464
# 12  2019           2355          492
