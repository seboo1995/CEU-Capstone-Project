# %%
# %pwd
# Out:
# '/home/sebair/CEU-Capstone-Project/Jupyter_Notebooks/reports_from_nget'

# %%
import tabula
import numpy as np

# %%
tass = tabula.read_pdf("2-nget-stat-and-regsmodel-2016-250716-web-version.pdf",pages = np.arange(35,45,1).tolist())
# Out:
# Got stderr: May 02, 2020 6:48:45 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font Arial are not implemented in PDFBox and will be ignored
# May 02, 2020 6:48:45 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font Arial are not implemented in PDFBox and will be ignored
# May 02, 2020 6:48:46 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font Arial are not implemented in PDFBox and will be ignored
# May 02, 2020 6:48:46 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font Arial,Bold are not implemented in PDFBox and will be ignored
# May 02, 2020 6:48:46 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font Arial are not implemented in PDFBox and will be ignored
# May 02, 2020 6:48:46 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# ...

# %%
tass[1]
# Out:
#                                            Unnamed: 0 Unnamed: 1   2016  \
# 0                                                 NaN      Notes     £m
# 1                                             Revenue       1(a)    NaN
# 2                            Exceptional other income          3    NaN
# 3                                     Operating costs          2    NaN
# 4                                    Operating profit        NaN    NaN
# 5                            Before exceptional items       1(b)  1,161
# 6                                   Exceptional items          3      -
# 7                              Total operating profit       1(b)    NaN
# 8                                      Finance income          4    NaN
# 9                                       Finance costs        NaN    NaN
# 10        Before exceptional items and remeasurements          4  (128)
# 11               Exceptional items and remeasurements       3, 4   (12)
# ...

# %%
for j in tass:
    for k in j.apply(lambda row: row.astype(str).str.contains('Operating costs').any(), axis=1):
        if k:
            temp = j
            break
            break

# %%
for j in temp.iteritems():
    for k in j:
        print("_____________")
        print(k)
# Out:
# _____________
# Revenue
# _____________
# 0                                 Operating costs
# 1                                Operating profit
# 2                        Before exceptional items
# 3                               Exceptional items
# 4                          Total operating profit
# 5              Interest income and similar income
# 6        Interest expense and other finance costs
# 7     Before exceptional items and remeasurements
# 8            Exceptional items and remeasurements
# 9                                             NaN
# 10                              Profit before tax
# 11    Before exceptional items and remeasurements
# 12           Exceptional items and remeasurements
# 13                        Total profit before tax
# 14                                       Taxation
# 15    Before exceptional items and remeasurements
# 16           Exceptional items and remeasurements
# 17                                 Total taxation
# ...

# %%
len(tass)
# Out:
# 18
