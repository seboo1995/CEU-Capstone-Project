# %% [markdown]
# ## Fisrst draft

# %%
# %pwd
# Out:
# '/home/sebair/CEU-Capstone-Project/Jupyter_Notebooks'

# %%
#importing dependecies
import pandas as pd
import numpy as np

# %% [markdown]
# I am using the spredsheet from national grid which can be found
# <a href = "https://www.nationalgrideso.com/document/5073 /download"> here </a> and I took screenshot of the spreadsheet, which can be seen below. I will use pandas for reading, so I will use the pandas read_excel function, however I will need to define the sheet_names, each sheet is for one year data .
#
# <img src = "../pics/worksheet.png" alt = "pic from screenshot">

# %% [markdown]
# From here we can see that the 2005 t0 2009 the sheet names are without the keyword "Dem"

# %%
#creating names
years = ["Dem "+ str(i)+"-"+str(i%100 + 1) for i in range(2005,2020)]

# %%
for i in range(len(years)):
    #last two digits of the years list
    temp = years[i].split("-")
    #the sheet names are of the form 2005-06
    if int(temp[1]) < 10:
        #the sheet for the years between 2005 and 2008 they
        #do not have the string "Dem"
        new_sheet_name = temp[0].split(" ")[1] + "-0" + temp[1]
        years[i] = new_sheet_name

# %%
years
# Out:
# ['2005-06',
#  '2006-07',
#  '2007-08',
#  '2008-09',
#  'Dem 2009-10',
#  'Dem 2010-11',
#  'Dem 2011-12',
#  'Dem 2012-13',
#  'Dem 2013-14',
#  'Dem 2014-15',
#  'Dem 2015-16',
#  'Dem 2016-17',
#  'Dem 2017-18',
#  'Dem 2018-19',
#  'Dem 2019-20']

# %% [markdown]
# I think these names should be fine

# %% [markdown]
# ## Now I will only read the demand tariffs

# %%
sheets = pd.read_excel("../Raw_data/TNUoS Tariffs 2005-06 to 2019-20.xlsx",
                   sheet_name= years,
                        # skip the first 5 rows because they are empty anyway
                       skiprows=5)

# %% [markdown]
# Each sheet is pandas dataframe, this is one example.

# %%
#this is for 2005
sheets[years[0]]
# Out:
#                                  Zone No.                         Zone Name  \
# 0                                       1                         Peterhead
# 1                                       2                    North Scotland
# 2                                       3                              Skye
# 3                                       4                  Western Highland
# 4                                       5                 Central Highlands
# 5                                       6                          Cruachan
# 6                                       7                            Argyll
# 7                                       8                     Stirlingshire
# 8                                       9                    South Scotland
# 9                                      10                North East England
# 10                                     11  Humber, Lancashire & SW Scotland
# 11                                     12                          Anglesey
# 12                                     13                          Dinorwig
# 13                                     14         South Yorks & North Wales
# 14                                     15             Midlands & South East
# 15                                     16                    Central London
# 16                                     17                     North London
# 17                                     18                Oxon & South Coast
# 18                                     19          South Wales & Gloucester
# 19                                     20                            Wessex
# 20                                     21                         Peninsula
# 21                                    NaN                               NaN
# 22  Residual Charge for Generation (£/kW)                               NaN
# 23      Residual Charge for Demand (£/kW)                               NaN
#
#     Zonal Tariff (£/kW)  Unnamed: 3  Zone No..1  \
# 0             18.162236         NaN         1.0
# 1             20.929759         NaN         2.0
# 2             23.095483         NaN         3.0
# 3             18.920247         NaN         4.0
# 4             15.360647         NaN         5.0
# 5             15.852828         NaN         6.0
# 6             13.441972         NaN         7.0
# 7             12.610665         NaN         8.0
# 8             11.820471         NaN         9.0
# 9              8.090616         NaN        10.0
# 10             4.906290         NaN        11.0
# 11             6.122706         NaN        12.0
# 12             8.705520         NaN        13.0
# 13             3.120190         NaN        14.0
# 14             1.322966         NaN         NaN
# 15            -5.712196         NaN         NaN
# 16            -0.220327         NaN         NaN
# 17            -0.698936         NaN         NaN
# 18            -2.552479         NaN         NaN
# 19            -4.951295         NaN         NaN
# 20            -8.044943         NaN         NaN
# 21                  NaN         NaN         NaN
# 22             3.257000         NaN         NaN
# 23            11.190000         NaN         NaN
#
#                                            Zone Name.  HH Zonal Tariff (£/kW)  \
# 0                                   Northern Scotland                0.041110
# 1                                   Southern Scotland                4.114438
# 2                                            Northern                7.393664
# 3                                          North West               11.137060
# 4                                           Yorkshire               11.182059
# 5                                    N Wales & Mersey               11.210216
# 6                                       East Midlands               13.465848
# 7                                            Midlands               15.026957
# 8                                             Eastern               14.028455
# 9                                         South Wales               18.315906
# 10                                         South East               15.989410
# 11                                             London               18.516693
# 12                                           Southern               17.833397
# 13                                      South Western               20.489868
# 14                                                NaN                     NaN
# 15  Demand tariffs include a 'small generators' ad...                0.041110
# 16                                                NaN                     NaN
# 17                                                NaN                     NaN
# 18                                                NaN                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21                                                NaN                     NaN
# 22                                                NaN                     NaN
# 23                                                NaN                     NaN
#
#     NHH Zonal Tariff (p/kWh)
# 0                   0.005610
# 1                   0.561693
# 2                   0.970234
# 3                   1.461966
# 4                   1.487585
# 5                   1.512416
# 6                   1.804975
# 7                   2.062601
# 8                   1.909865
# 9                   2.368863
# 10                  2.167559
# 11                  2.454909
# 12                  2.446575
# 13                  2.728435
# 14                       NaN
# 15                  0.005610
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN

# %% [markdown]
# From 2005 to 2009 the demand and generator tariffs(I assume, I will need a second check from you) are on the same spreadsheet so I have to separate them(filter them out)

# %% [markdown]
# Below is the dataframe for 2005

# %%
for i,j in sheets.items():
    try:
        if int(i.split("-")[0]) <= 2008:
            print("This is for",i)
            #print( sheets[i][sheets[i].columns[2:]][0:35])
#            print("---------------------------------------")
            temp = sheets[i][sheets[i].columns[2:]][0:35]
            sheets[i] = temp
            #new columns as year
            sheets[i]["year"] = i.split("-")[0]
            #new column for generator adjustment
            hh_gen_adj = sheets[i].loc[15,"HH Zonal Tariff (£/kW)"]
            nhh_gen_adj = sheets[i].loc[15,"NHH Zonal Tariff (p/kWh)"]
            sheets[i]["HH_gen_adj"] = hh_gen_adj
            sheets[i]["NHH_gen_adj"] = nhh_gen_adj
            #adding the residual
            if  int(i.split("-")[0]) == 2005:
                sheets[i]["residual"] = sheets[i].loc[sheets[i].shape[0]-1,"Zonal Tariff (£/kW)"]
            else:
                sheets[i]["residual"] = sheets[i].loc[sheets[i].shape[0]-1,"Zone No..1"]
            
            sheets[i] = sheets[i][sheets[i].columns[3:]][1:14]

    #this acts as the embeded else, because it gets me the error
    #for invalid itteral(meaning that I have strings and I see
    #it as number)
    except Exception as e:
        #print("excepption")
        #year = i.split(" ")[0]
        print(e)
        pass
# Out:
# This is for 2005-06
# This is for 2006-07
# This is for 2007-08
# This is for 2008-09
# invalid literal for int() with base 10: 'Dem 2009'
# invalid literal for int() with base 10: 'Dem 2010'
# invalid literal for int() with base 10: 'Dem 2011'
# invalid literal for int() with base 10: 'Dem 2012'
# invalid literal for int() with base 10: 'Dem 2013'
# invalid literal for int() with base 10: 'Dem 2014'
# invalid literal for int() with base 10: 'Dem 2015'
# invalid literal for int() with base 10: 'Dem 2016'
# invalid literal for int() with base 10: 'Dem 2017'
# invalid literal for int() with base 10: 'Dem 2018'
# invalid literal for int() with base 10: 'Dem 2019'

# %% [markdown]
# Now the dataframes look like this

# %%
sheets["2005-06"]
# Out:
#            Zone Name.  HH Zonal Tariff (£/kW)  NHH Zonal Tariff (p/kWh)  year  \
# 1   Southern Scotland                4.114438                  0.561693  2005
# 2            Northern                7.393664                  0.970234  2005
# 3          North West               11.137060                  1.461966  2005
# 4           Yorkshire               11.182059                  1.487585  2005
# 5    N Wales & Mersey               11.210216                  1.512416  2005
# 6       East Midlands               13.465848                  1.804975  2005
# 7            Midlands               15.026957                  2.062601  2005
# 8             Eastern               14.028455                  1.909865  2005
# 9         South Wales               18.315906                  2.368863  2005
# 10         South East               15.989410                  2.167559  2005
# 11             London               18.516693                  2.454909  2005
# 12           Southern               17.833397                  2.446575  2005
# 13      South Western               20.489868                  2.728435  2005
#
#     HH_gen_adj  NHH_gen_adj  residual
# 1      0.04111      0.00561     11.19
# 2      0.04111      0.00561     11.19
# 3      0.04111      0.00561     11.19
# 4      0.04111      0.00561     11.19
# 5      0.04111      0.00561     11.19
# 6      0.04111      0.00561     11.19
# 7      0.04111      0.00561     11.19
# 8      0.04111      0.00561     11.19
# 9      0.04111      0.00561     11.19
# 10     0.04111      0.00561     11.19
# 11     0.04111      0.00561     11.19
# 12     0.04111      0.00561     11.19
# 13     0.04111      0.00561     11.19

# %%
import re
for i,j in sheets.items():
    if i.startswith("Dem"):
        year= i.split(" ")[1].split("-")[0]
        print("year",year)
        print("For sheet",i,"the shape is",sheets[i].shape)
        #Until 2012 its fine
        if(int(year) <= 2012 ):
            print("The residual demand tariff is  ", sheets[i].iloc[18,4])
            res_demand = sheets[i].iloc[18,4]
            sheets[i]["residual_demand"] = res_demand
            
            print("__________________________________")
        elif int(year) >= 2013 and int(year) <= 2016:
            print("The HH Zonal tariff for small gen",sheets[i].iloc[15,3])
            sheets[i]["hh_small_gen_tariff"] = sheets[i].iloc[15,3]
            print("The NHH Zonal tariff for small gen",sheets[i].iloc[15,4])
            sheets[i]["nhh_small_gen_tariff"] =  sheets[i].iloc[15,4]
            print("The residual demand tariff is  ", sheets[i].iloc[18,4])
            sheets[i]["residual_demand"] = sheets[i].iloc[18,4]
            print("__________________________________")
        else:
            #it contains characters, but I excluded the pound sign
            print("The HH Zonal tariff for small gen",re.sub('[^0-9,.]', '', sheets[i].iloc[15,3]))
            sheets[i]["hh_small_gen_tariff"] = re.sub('[^0-9,.]', '', sheets[i].iloc[15,3])
            print("The NHH Zonal tariff for small gen",re.sub('[^0-9,.]', '', sheets[i].iloc[15,4]))
            sheets[i]["nhh_small_gen_tariff"] = re.sub('[^0-9,.]', '', sheets[i].iloc[15,4])
            print("The residual demand tariff is  ", sheets[i].iloc[18,4])
            sheets[i]["residual_demand"] = re.sub('[^0-9,.]', '', str(sheets[i].iloc[18,4]))
            print("__________________________________")
# Out:
# year 2009
# For sheet Dem 2009-10 the shape is (20, 5)
# The HH Zonal tariff for small gen 0.0893
# The NHH Zonal tariff for small gen 0.011304
# The residual demand tariff is   16.943693697313442
# __________________________________
# year 2010
# For sheet Dem 2010-11 the shape is (21, 5)
# The HH Zonal tariff for small gen 0.12380338289354835
# The NHH Zonal tariff for small gen 0.01704973923585892
# The residual demand tariff is   18.558559862804156
# __________________________________
# year 2011
# For sheet Dem 2011-12 the shape is (20, 5)
# The HH Zonal tariff for small gen 0.12905793587548497
# The NHH Zonal tariff for small gen 0.01800602129396801
# The residual demand tariff is   3.60793266095396
# __________________________________
# year 2012
# For sheet Dem 2012-13 the shape is (20, 5)
# The HH Zonal tariff for small gen 0.1666147351910715
# The NHH Zonal tariff for small gen 0.023366148085556863
# The residual demand tariff is   22.82837287031424
# __________________________________
# year 2013
# For sheet Dem 2013-14 the shape is (19, 5)
# The HH Zonal tariff for small gen 0.19372446636160712
# The NHH Zonal tariff for small gen 0.02702659513226616
# The residual demand tariff is   25.408453823505752
# __________________________________
# year 2014
# For sheet Dem 2014-15 the shape is (19, 5)
# The HH Zonal tariff for small gen 0.26132717354231466
# The NHH Zonal tariff for small gen 0.03600215837948993
# The residual demand tariff is   30.052441673120608
# __________________________________
# year 2015
# For sheet Dem 2015-16 the shape is (19, 5)
# The HH Zonal tariff for small gen 0.3508904483326336
# The NHH Zonal tariff for small gen 0.04792927095013303
# The residual demand tariff is   35.63495547972327
# __________________________________
# year 2016
# For sheet Dem 2016-17 the shape is (19, 5)
# The HH Zonal tariff for small gen 0.5304531462680724
# The NHH Zonal tariff for small gen 0.07445403119294647
# The residual demand tariff is   45.333825773085
# __________________________________
# year 2017
# For sheet Dem 2017-18 the shape is (19, 5)
# The HH Zonal tariff for small gen 0.552245
# The NHH Zonal tariff for small gen 0.0751737
# The residual demand tariff is   47.260756295627864
# __________________________________
# year 2018
# For sheet Dem 2018-19 the shape is (19, 6)
# The HH Zonal tariff for small gen 0.593
# The NHH Zonal tariff for small gen 0.080127
# The residual demand tariff is   46.933426
# __________________________________
# year 2019
# For sheet Dem 2019-20 the shape is (19, 6)
# The HH Zonal tariff for small gen 0.618659
# The NHH Zonal tariff for small gen 0.080795
# The residual demand tariff is   50.78039
# __________________________________

# %%
sheets["Dem 2019-20"]
# Out:
#     Unnamed: 0                                  Zone  \
# 0          NaN                                     1
# 1          NaN                                     2
# 2          NaN                                     3
# 3          NaN                                     4
# 4          NaN                                     5
# 5          NaN                                     6
# 6          NaN                                     7
# 7          NaN                                     8
# 8          NaN                                     9
# 9          NaN                                    10
# 10         NaN                                    11
# 11         NaN                                    12
# 12         NaN                                    13
# 13         NaN                                    14
# 14         NaN                                   NaN
# 15         NaN  Tariffs include small gen tariff of:
# 16         NaN                                   NaN
# 17         NaN                                   NaN
# 18         NaN                                   NaN
#
#                                Zone Name HH Demand Tariff\n(£/kW)  \
# 0                      Northern Scotland                  20.9713
# 1                      Southern Scotland                  30.7554
# 2                               Northern                  41.0267
# 3                             North West                  47.8316
# 4                              Yorkshire                  48.0393
# 5                       N Wales & Mersey                  49.3454
# 6                          East Midlands                  51.4398
# 7                               Midlands                  52.9281
# 8                                Eastern                  53.7883
# 9                            South Wales                  49.7256
# 10                            South East                  56.1108
# 11                                London                  59.1758
# 12                              Southern                  57.3388
# 13                         South Western                  55.6867
# 14                                   NaN                      NaN
# 15                                   NaN             £0.618659/kW
# 16                                   NaN                      NaN
# 17  Residual Charge for Generation(£/kW)                      NaN
# 18     Residual Charge for Demand (£/kW)                      NaN
#
#    NHH Demand Tariff\n(p/kWh)  Embedded Export Tariff (£/kW)  \
# 0                     2.82045                       0.000000
# 1                     4.02604                       0.000000
# 2                     5.21383                       7.604902
# 3                     6.20228                      14.409800
# 4                     6.11633                      14.617537
# 5                     6.22376                      15.923587
# 6                     6.73856                      18.017989
# 7                     6.97743                      19.506286
# 8                     7.49669                      20.366546
# 9                     5.87329                      16.303862
# 10                    7.94565                      22.689070
# 11                     6.2914                      25.754007
# 12                    7.58602                      23.917000
# 13                    7.76749                      22.264898
# 14                        NaN                            NaN
# 15              0.080795p/kWh                            NaN
# 16                        NaN                            NaN
# 17                   -3.52753                            NaN
# 18                    50.7804                            NaN
#
#    hh_small_gen_tariff nhh_small_gen_tariff residual_demand
# 0             0.618659             0.080795        50.78039
# 1             0.618659             0.080795        50.78039
# 2             0.618659             0.080795        50.78039
# 3             0.618659             0.080795        50.78039
# 4             0.618659             0.080795        50.78039
# 5             0.618659             0.080795        50.78039
# 6             0.618659             0.080795        50.78039
# 7             0.618659             0.080795        50.78039
# 8             0.618659             0.080795        50.78039
# 9             0.618659             0.080795        50.78039
# 10            0.618659             0.080795        50.78039
# 11            0.618659             0.080795        50.78039
# 12            0.618659             0.080795        50.78039
# 13            0.618659             0.080795        50.78039
# 14            0.618659             0.080795        50.78039
# 15            0.618659             0.080795        50.78039
# 16            0.618659             0.080795        50.78039
# 17            0.618659             0.080795        50.78039
# 18            0.618659             0.080795        50.78039

# %% [markdown]
# Because I have only 14 zones I will only get the first 14 rows of every dataframe

# %%
for i,j in sheets.items():
    sheets[i] = sheets[i][:14]

# %%
sheets["Dem 2012-13"]
# Out:
#    Zone No.         Zone Name. HH Zonal Tariff (£/kW)  \
# 0         1  Northern Scotland                10.7414
# 1         2  Southern Scotland                16.0017
# 2         3           Northern                19.6628
# 3         4         North West                22.8387
# 4         5          Yorkshire                23.1802
# 5         6   N Wales & Mersey                23.6395
# 6         7      East Midlands                25.4515
# 7         8           Midlands                27.3582
# 8         9            Eastern                 25.952
# 9        10        South Wales                25.2573
# 10       11         South East                28.2481
# 11       12             London                31.1746
# 12       13           Southern                30.6134
# 13       14      South Western                31.0627
#
#     NHH Zonal Tariff (p/kWh)  Unnamed: 4  hh_small_gen_tariff  \
# 0                   1.481661         NaN             0.166615
# 1                   2.260958         NaN             0.166615
# 2                   2.720973         NaN             0.166615
# 3                   3.310579         NaN             0.166615
# 4                   3.216258         NaN             0.166615
# 5                   3.392395         NaN             0.166615
# 6                   3.602558         NaN             0.166615
# 7                   3.936288         NaN             0.166615
# 8                   3.633328         NaN             0.166615
# 9                   3.368021         NaN             0.166615
# 10                  3.987297         NaN             0.166615
# 11                  4.169758         NaN             0.166615
# 12                  4.343659         NaN             0.166615
# 13                  4.226735         NaN             0.166615
#
#     nhh_small_gen_tariff  residual_demand
# 0               0.023366        22.828373
# 1               0.023366        22.828373
# 2               0.023366        22.828373
# 3               0.023366        22.828373
# 4               0.023366        22.828373
# 5               0.023366        22.828373
# 6               0.023366        22.828373
# 7               0.023366        22.828373
# 8               0.023366        22.828373
# 9               0.023366        22.828373
# 10              0.023366        22.828373
# 11              0.023366        22.828373
# 12              0.023366        22.828373
# 13              0.023366        22.828373

# %%
sheets['Dem 2009-10']
# Out:
#    Zone No.         Zone Name. HH Zonal Tariff (£/kW)  \
# 0         1  Northern Scotland                3.37924
# 1         2  Southern Scotland                9.06643
# 2         3           Northern                12.0594
# 3         4         North West                16.5429
# 4         5          Yorkshire                16.2979
# 5         6   N Wales & Mersey                16.8887
# 6         7      East Midlands                19.1302
# 7         8           Midlands                20.5266
# 8         9            Eastern                20.0057
# 9        10        South Wales                23.6837
# 10       11         South East                23.8441
# 11       12             London                25.9047
# 12       13           Southern                24.4715
# 13       14      South Western                25.6316
#
#     NHH Zonal Tariff (p/kWh)  Unnamed: 4  hh_small_gen_tariff  \
# 0                   0.459137         NaN               0.0893
# 1                   1.138085         NaN               0.0893
# 2                   1.598288         NaN               0.0893
# 3                   2.095188         NaN               0.0893
# 4                   2.126680         NaN               0.0893
# 5                   2.028429         NaN               0.0893
# 6                   2.469531         NaN               0.0893
# 7                   2.705483         NaN               0.0893
# 8                   2.526505         NaN               0.0893
# 9                   2.938924         NaN               0.0893
# 10                  3.061244         NaN               0.0893
# 11                  3.033868         NaN               0.0893
# 12                  3.016744         NaN               0.0893
# 13                  3.200032         NaN               0.0893
#
#     nhh_small_gen_tariff  residual_demand
# 0               0.011304        16.943694
# 1               0.011304        16.943694
# 2               0.011304        16.943694
# 3               0.011304        16.943694
# 4               0.011304        16.943694
# 5               0.011304        16.943694
# 6               0.011304        16.943694
# 7               0.011304        16.943694
# 8               0.011304        16.943694
# 9               0.011304        16.943694
# 10              0.011304        16.943694
# 11              0.011304        16.943694
# 12              0.011304        16.943694
# 13              0.011304        16.943694

# %%
sheets["Dem 2019-20"]
# Out:
#     Unnamed: 0 Zone          Zone Name HH Demand Tariff\n(£/kW)  \
# 0          NaN    1  Northern Scotland                  20.9713
# 1          NaN    2  Southern Scotland                  30.7554
# 2          NaN    3           Northern                  41.0267
# 3          NaN    4         North West                  47.8316
# 4          NaN    5          Yorkshire                  48.0393
# 5          NaN    6   N Wales & Mersey                  49.3454
# 6          NaN    7      East Midlands                  51.4398
# 7          NaN    8           Midlands                  52.9281
# 8          NaN    9            Eastern                  53.7883
# 9          NaN   10        South Wales                  49.7256
# 10         NaN   11         South East                  56.1108
# 11         NaN   12             London                  59.1758
# 12         NaN   13           Southern                  57.3388
# 13         NaN   14      South Western                  55.6867
#
#    NHH Demand Tariff\n(p/kWh)  Embedded Export Tariff (£/kW)  \
# 0                     2.82045                       0.000000
# 1                     4.02604                       0.000000
# 2                     5.21383                       7.604902
# 3                     6.20228                      14.409800
# 4                     6.11633                      14.617537
# 5                     6.22376                      15.923587
# 6                     6.73856                      18.017989
# 7                     6.97743                      19.506286
# 8                     7.49669                      20.366546
# 9                     5.87329                      16.303862
# 10                    7.94565                      22.689070
# 11                     6.2914                      25.754007
# 12                    7.58602                      23.917000
# 13                    7.76749                      22.264898
#
#    hh_small_gen_tariff nhh_small_gen_tariff residual_demand
# 0             0.618659             0.080795        50.78039
# 1             0.618659             0.080795        50.78039
# 2             0.618659             0.080795        50.78039
# 3             0.618659             0.080795        50.78039
# 4             0.618659             0.080795        50.78039
# 5             0.618659             0.080795        50.78039
# 6             0.618659             0.080795        50.78039
# 7             0.618659             0.080795        50.78039
# 8             0.618659             0.080795        50.78039
# 9             0.618659             0.080795        50.78039
# 10            0.618659             0.080795        50.78039
# 11            0.618659             0.080795        50.78039
# 12            0.618659             0.080795        50.78039
# 13            0.618659             0.080795        50.78039

# %% [markdown]
# In all the sheets there is a column called Unnamed, so I will drop all of them

# %%
for sheet in sheets:
    for col in sheets[sheet]: 
        if col.startswith("Unnamed"):
            print("For sheet",sheet,"the column",col,"will be dropped")
            sheets[sheet].drop([col],axis=1,inplace=True)
# Out:
# For sheet Dem 2009-10 the column Unnamed: 4 will be dropped
# For sheet Dem 2010-11 the column Unnamed: 4 will be dropped
# For sheet Dem 2011-12 the column Unnamed: 4 will be dropped
# For sheet Dem 2012-13 the column Unnamed: 4 will be dropped
# For sheet Dem 2013-14 the column Unnamed: 0 will be dropped
# For sheet Dem 2014-15 the column Unnamed: 0 will be dropped
# For sheet Dem 2015-16 the column Unnamed: 0 will be dropped
# For sheet Dem 2016-17 the column Unnamed: 0 will be dropped
# For sheet Dem 2017-18 the column Unnamed: 0 will be dropped
# For sheet Dem 2018-19 the column Unnamed: 0 will be dropped
# For sheet Dem 2019-20 the column Unnamed: 0 will be dropped
# /home/sebair/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
sheets["Dem 2009-10"]
# Out:
#    Zone No.         Zone Name. HH Zonal Tariff (£/kW)  \
# 0         1  Northern Scotland                3.37924
# 1         2  Southern Scotland                9.06643
# 2         3           Northern                12.0594
# 3         4         North West                16.5429
# 4         5          Yorkshire                16.2979
# 5         6   N Wales & Mersey                16.8887
# 6         7      East Midlands                19.1302
# 7         8           Midlands                20.5266
# 8         9            Eastern                20.0057
# 9        10        South Wales                23.6837
# 10       11         South East                23.8441
# 11       12             London                25.9047
# 12       13           Southern                24.4715
# 13       14      South Western                25.6316
#
#     NHH Zonal Tariff (p/kWh)  hh_small_gen_tariff  nhh_small_gen_tariff  \
# 0                   0.459137               0.0893              0.011304
# 1                   1.138085               0.0893              0.011304
# 2                   1.598288               0.0893              0.011304
# 3                   2.095188               0.0893              0.011304
# 4                   2.126680               0.0893              0.011304
# 5                   2.028429               0.0893              0.011304
# 6                   2.469531               0.0893              0.011304
# 7                   2.705483               0.0893              0.011304
# 8                   2.526505               0.0893              0.011304
# 9                   2.938924               0.0893              0.011304
# 10                  3.061244               0.0893              0.011304
# 11                  3.033868               0.0893              0.011304
# 12                  3.016744               0.0893              0.011304
# 13                  3.200032               0.0893              0.011304
#
#     residual_demand
# 0         16.943694
# 1         16.943694
# 2         16.943694
# 3         16.943694
# 4         16.943694
# 5         16.943694
# 6         16.943694
# 7         16.943694
# 8         16.943694
# 9         16.943694
# 10        16.943694
# 11        16.943694
# 12        16.943694
# 13        16.943694

# %% [markdown]
# I think I forgot to add year column in the sheets that are from 2009 until 2019

# %%
for sheet in sheets:
    if sheet.startswith("Dem"):
        print("Adding year column to sheet",sheet)
        temp = sheet.split("-")
        year = ''.join(filter(lambda i: i.isdigit(), temp[0]))
        sheets[sheet]['year'] = year
        print("Finished with sheet",sheet)
# Out:
# Adding year column to sheet Dem 2009-10
# Finished with sheet Dem 2009-10
# Adding year column to sheet Dem 2010-11
# Finished with sheet Dem 2010-11
# Adding year column to sheet Dem 2011-12
# Finished with sheet Dem 2011-12
# Adding year column to sheet Dem 2012-13
# Finished with sheet Dem 2012-13
# Adding year column to sheet Dem 2013-14
# Finished with sheet Dem 2013-14
# Adding year column to sheet Dem 2014-15
# Finished with sheet Dem 2014-15
# Adding year column to sheet Dem 2015-16
# Finished with sheet Dem 2015-16
# Adding year column to sheet Dem 2016-17
# Finished with sheet Dem 2016-17
# Adding year column to sheet Dem 2017-18
# Finished with sheet Dem 2017-18
# Adding year column to sheet Dem 2018-19
# Finished with sheet Dem 2018-19
# Adding year column to sheet Dem 2019-20
# Finished with sheet Dem 2019-20
# /home/sebair/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sheets["Dem 2019-20"]
# Out:
#    Zone          Zone Name HH Demand Tariff\n(£/kW)  \
# 0     1  Northern Scotland                  20.9713
# 1     2  Southern Scotland                  30.7554
# 2     3           Northern                  41.0267
# 3     4         North West                  47.8316
# 4     5          Yorkshire                  48.0393
# 5     6   N Wales & Mersey                  49.3454
# 6     7      East Midlands                  51.4398
# 7     8           Midlands                  52.9281
# 8     9            Eastern                  53.7883
# 9    10        South Wales                  49.7256
# 10   11         South East                  56.1108
# 11   12             London                  59.1758
# 12   13           Southern                  57.3388
# 13   14      South Western                  55.6867
#
#    NHH Demand Tariff\n(p/kWh)  Embedded Export Tariff (£/kW)  \
# 0                     2.82045                       0.000000
# 1                     4.02604                       0.000000
# 2                     5.21383                       7.604902
# 3                     6.20228                      14.409800
# 4                     6.11633                      14.617537
# 5                     6.22376                      15.923587
# 6                     6.73856                      18.017989
# 7                     6.97743                      19.506286
# 8                     7.49669                      20.366546
# 9                     5.87329                      16.303862
# 10                    7.94565                      22.689070
# 11                     6.2914                      25.754007
# 12                    7.58602                      23.917000
# 13                    7.76749                      22.264898
#
#    hh_small_gen_tariff nhh_small_gen_tariff residual_demand  year
# 0             0.618659             0.080795        50.78039  2019
# 1             0.618659             0.080795        50.78039  2019
# 2             0.618659             0.080795        50.78039  2019
# 3             0.618659             0.080795        50.78039  2019
# 4             0.618659             0.080795        50.78039  2019
# 5             0.618659             0.080795        50.78039  2019
# 6             0.618659             0.080795        50.78039  2019
# 7             0.618659             0.080795        50.78039  2019
# 8             0.618659             0.080795        50.78039  2019
# 9             0.618659             0.080795        50.78039  2019
# 10            0.618659             0.080795        50.78039  2019
# 11            0.618659             0.080795        50.78039  2019
# 12            0.618659             0.080795        50.78039  2019
# 13            0.618659             0.080795        50.78039  2019

# %% [markdown]
# ## Quesion 1: In the spreadsheet there are demand and generator charges for years 2005 to 2008. For now the HH zonal tariff and NHH zonal tariff will be inputs. Which one should I take for the residual?

# %% [markdown]
# ## Question2:  Which demand zone is SSE. I think Southern Scotland?
